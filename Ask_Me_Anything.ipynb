# %%
from transformers import pipeline

# %%
# Load QA pipeline
qa_pipeline = pipeline("question-answering", model="deepset/bert-base-cased-squad2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForQuestionAnswering LOAD REPORT from: deepset/bert-base-cased-squad2
# ...

# %%
context = """
Artificial Intelligence (AI) is a branch of computer science that focuses on building intelligent systems.
Machine Learning is a subset of AI that allows systems to learn from data.
Deep Learning is a specialized type of Machine Learning that uses neural networks with many layers.
Python is one of the most popular programming languages used in AI development.
AI is widely used in healthcare, finance, and transportation industries.
"""

# %%
questions = [
    "What is Artificial Intelligence?",
    "What is Machine Learning?",
    "Which programming language is popular for AI?",
    "Where is AI widely used?"
]

for question in questions:
    result = qa_pipeline(question=question, context=context)
    print("Question:", question)
    print("Answer:", result['answer'])
    print("Confidence Score:", result['score'])
    print("-" * 50)
# Out:
# Question: What is Artificial Intelligence?
# Answer: a branch of computer science
# Confidence Score: 0.3179934322834015
# --------------------------------------------------
# Question: What is Machine Learning?
# Answer: a subset of AI that allows systems to learn from data
# Confidence Score: 0.3869001269340515
# --------------------------------------------------
# Question: Which programming language is popular for AI?
# Answer: Python
# Confidence Score: 0.997960090637207
# --------------------------------------------------
# Question: Where is AI widely used?
# Answer: healthcare, finance, and transportation industries
# Confidence Score: 0.6912434101104736
# --------------------------------------------------

# %% [markdown]
# ### Accuracy Analysis
#
# The model performed very well on direct factual questions.
#
# It extracted exact phrases from the context.
#
# Confidence scores were above 0.95, indicating high reliability.
#
# Since the context was clear and structured, BERT performed accurately.
#
# The model may struggle if:
#
# Questions are ambiguous.
#
# The answer is not directly present in the context.
#
# The question requires reasoning beyond the text.
